# %% [markdown]
# <a href="https://colab.research.google.com/github/vaibhavi-kulkarni/DM/blob/main/Untitled12dm2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importing necessary libraries
import pandas as pd
import numpy as np
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.metrics import classification_report, confusion_matrix

# %%
df = pd.read_csv("2016-Q1-Trips-History-Data.csv")
df.head()
# Out:
#    Duration (ms)       Start date         End date  Start station number  \
# 0         301295  3/31/2016 23:59    4/1/2016 0:04                 31280
# 1         557887  3/31/2016 23:59    4/1/2016 0:08                 31275
# 2         555944  3/31/2016 23:59    4/1/2016 0:08                 31101
# 3         766916  3/31/2016 23:57    4/1/2016 0:09                 31226
# 4         139656  3/31/2016 23:57  3/31/2016 23:59                 31011
#
#                     Start station  End station number  \
# 0                  11th & S St NW               31506
# 1  New Hampshire Ave & 24th St NW               31114
# 2                  14th & V St NW               31221
# 3      34th St & Wisconsin Ave NW               31214
# 4               23rd & Crystal Dr               31009
#
#                  End station Bike number Member Type
# 0  1st & Rhode Island Ave NW      W00022  Registered
# 1   18th St & Wyoming Ave NW      W01294  Registered
# ...

# %%
address=df['End station'].unique()
print(address)
df = df.dropna()
# Out:
# ['1st & Rhode Island Ave NW' '18th St & Wyoming Ave NW' '18th & M St NW'
#  '17th & Corcoran St NW' '27th & Crystal Dr' '5th & K St NW'
#  '18th & R St NW' '20th & O St NW / Dupont South'
#  '5th St & Massachusetts Ave NW' '1st & N St  SE'
#  '21st St N & N Pierce St' '3rd St & Pennsylvania Ave SE'
#  'Eckington Pl & Q St NE' '34th St & Wisconsin Ave NW'
#  'Bladensburg Rd & Benning Rd NE' '2nd & G St NE'
#  'Smithsonian / Jefferson Dr & 12th St SW' '21st & M St NW'
#  'Lincoln Memorial' 'Lee Hwy & N Cleveland St' '15th & Euclid St  NW'
#  'M St & New Jersey Ave SE' 'Massachusetts Ave & Dupont Circle NW'
#  'Gallaudet / 8th St & Florida Ave NE' '10th & Florida Ave NW'
#  'Constitution Ave & 2nd St NW/DOL' '14th & Belmont St NW'
#  'Columbus Circle / Union Station' 'Lamont & Mt Pleasant NW'
#  'Neal St & Trinidad Ave NE' 'N Veitch & Key Blvd'
#  '14th & Rhode Island Ave NW' 'N Quincy St & Wilson Blvd' '14th & V St NW'
#  '14th & Harvard St NW' 'Harvard St & Adams Mill Rd NW'
# ...

# %%
from sklearn.preprocessing import LabelEncoder
gle = LabelEncoder()
address_labels = gle.fit_transform(df['End station'])
address_labels = gle.fit_transform(df['Start station'])
address_mappings = {index: label for index, label in
                  enumerate(gle.classes_)}
address_mappings
# Out:
# {0: '10th & E St NW',
#  1: '10th & Florida Ave NW',
#  2: '10th & K St NW',
#  3: '10th & Monroe St NE',
#  4: '10th & U St NW',
#  5: '10th St & Constitution Ave NW',
#  6: '11th & F St NW',
#  7: '11th & H St NE',
#  8: '11th & Kenyon St NW',
#  9: '11th & M St NW',
#  10: '11th & S St NW',
#  11: '12th & Army Navy Dr',
#  12: '12th & Irving St NE',
#  13: '12th & L St NW',
#  14: '12th & Newton St NE',
#  15: '12th & U St NW',
#  16: '13th & D St NE',
#  17: '13th & H St NE',
#  18: '13th St & Eastern Ave',
#  19: '13th St & New York Ave NW',
#  20: '14th & Belmont St NW',
#  21: '14th & D St NW / Ronald Reagan Building',
#  22: '14th & D St SE',
#  23: '14th & G St NW',
#  24: '14th & Harvard St NW',
#  25: '14th & R St NW',
#  26: '14th & Rhode Island Ave NW',
#  27: '14th & Upshur St NW',
#  28: '14th & V St NW',
#  29: '14th St & Colorado Ave NW',
#  30: '14th St & New York Ave NW',
#  31: '14th St & Spring Rd NW',
#  32: '14th St Heights / 14th & Crittenden St NW',
# ...

# %%
df['End station'] = address_labels

# %%
gle = LabelEncoder()
address_labels = gle.fit_transform(df['Start station'])
address_mappings = {index: label for index, label in
                  enumerate(gle.classes_)}
address_mappings
# Out:
# {0: '10th & E St NW',
#  1: '10th & Florida Ave NW',
#  2: '10th & K St NW',
#  3: '10th & Monroe St NE',
#  4: '10th & U St NW',
#  5: '10th St & Constitution Ave NW',
#  6: '11th & F St NW',
#  7: '11th & H St NE',
#  8: '11th & Kenyon St NW',
#  9: '11th & M St NW',
#  10: '11th & S St NW',
#  11: '12th & Army Navy Dr',
#  12: '12th & Irving St NE',
#  13: '12th & L St NW',
#  14: '12th & Newton St NE',
#  15: '12th & U St NW',
#  16: '13th & D St NE',
#  17: '13th & H St NE',
#  18: '13th St & Eastern Ave',
#  19: '13th St & New York Ave NW',
#  20: '14th & Belmont St NW',
#  21: '14th & D St NW / Ronald Reagan Building',
#  22: '14th & D St SE',
#  23: '14th & G St NW',
#  24: '14th & Harvard St NW',
#  25: '14th & R St NW',
#  26: '14th & Rhode Island Ave NW',
#  27: '14th & Upshur St NW',
#  28: '14th & V St NW',
#  29: '14th St & Colorado Ave NW',
#  30: '14th St & New York Ave NW',
#  31: '14th St & Spring Rd NW',
#  32: '14th St Heights / 14th & Crittenden St NW',
# ...

# %%
df['Start station'] = address_labels

# %%
df.head()
# Out:
#    Duration (ms)       Start date         End date  Start station number  \
# 0         301295  3/31/2016 23:59    4/1/2016 0:04                 31280
# 1         557887  3/31/2016 23:59    4/1/2016 0:08                 31275
# 2         555944  3/31/2016 23:59    4/1/2016 0:08                 31101
# 3         766916  3/31/2016 23:57    4/1/2016 0:09                 31226
# 4         139656  3/31/2016 23:57  3/31/2016 23:59                 31011
#
#    Start station  End station number  End station Bike number Member Type
# 0             10               31506           10      W00022  Registered
# 1            275               31114          275      W01294  Registered
# 2             28               31221           28      W01416  Registered
# 3             95               31214           95      W01090  Registered
# 4             83               31009           83      W21934  Registered

# %%
gle = LabelEncoder()
bike_labels = gle.fit_transform(df['Bike number'])
bike_mappings = {index: label for index, label in
                  enumerate(gle.classes_)}
bike_mappings
# Out:
# {0: 'W00005',
#  1: 'W00006',
#  2: 'W00008',
#  3: 'W00009',
#  4: 'W00010',
#  5: 'W00011',
#  6: 'W00012',
#  7: 'W00013',
#  8: 'W00014',
#  9: 'W00015',
#  10: 'W00016',
#  11: 'W00017',
#  12: 'W00019',
#  13: 'W00020',
#  14: 'W00021',
#  15: 'W00022',
#  16: 'W00025',
#  17: 'W00027',
#  18: 'W00028',
#  19: 'W00029',
#  20: 'W00030',
#  21: 'W00031',
#  22: 'W00032',
#  23: 'W00033',
#  24: 'W00034',
#  25: 'W00035',
#  26: 'W00036',
#  27: 'W00037',
#  28: 'W00038',
#  29: 'W00039',
#  30: 'W00041',
#  31: 'W00042',
#  32: 'W00043',
#  33: 'W00044',
#  34: 'W00045',
#  35: 'W00046',
#  36: 'W00047',
#  37: 'W00049',
#  38: 'W00050',
#  39: 'W00054',
#  40: 'W00055',
#  41: 'W00057',
#  42: 'W00058',
#  43: 'W00060',
#  44: 'W00064',
#  45: 'W00065',
#  46: 'W00066',
#  47: 'W00068',
#  48: 'W00069',
#  49: 'W00074',
#  50: 'W00075',
#  51: 'W00076',
#  52: 'W00077',
#  53: 'W00078',
#  54: 'W00080',
#  55: 'W00083',
#  56: 'W00084',
#  57: 'W00085',
#  58: 'W00086',
# ...
